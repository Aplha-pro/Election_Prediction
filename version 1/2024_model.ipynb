# %%
import pandas as pd
import numpy as np
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential, Model
from keras.layers import LSTM, Dense, Embedding, Dropout, Input, Concatenate
from sklearn.model_selection import train_test_split
from keras.preprocessing.text import Tokenizer
from keras.models import load_model
from google.colab import drive

# %%
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
forth_model = load_model('/content/drive/MyDrive/Election Project/fourth_model.h5')
# Out:
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.

# %%
df_2024 = pd.read_csv('/content/drive/MyDrive/Election Project/Election 2024.csv')
df_2024.isnull().sum()
# Out:
# NO. OF CONSTITUENCY     0
# NAME OF CONSTITUENCY    0
# NAME OF PROVINCE        0
# POPULATION              0
# Party                   0
# Candidates              0
# dtype: int64

# %%
df_2024.head()
# Out:
#   NO. OF CONSTITUENCY             NAME OF CONSTITUENCY    NAME OF PROVINCE  \
# 0                NA-1  Chitral Upper-cum-Chitral Lower  Khyber Pakhtunkhwa
# 1                NA-1  Chitral Upper-cum-Chitral Lower  Khyber Pakhtunkhwa
# 2                NA-1  Chitral Upper-cum-Chitral Lower  Khyber Pakhtunkhwa
# 3                NA-1  Chitral Upper-cum-Chitral Lower  Khyber Pakhtunkhwa
# 4                NA-1  Chitral Upper-cum-Chitral Lower  Khyber Pakhtunkhwa
#
#   POPULATION                    Party               Candidates
# 0    515,935                       PPP             Fazli Rabbi
# 1    515,935                    JUI(F)  Muhammad Talha Mahmood
# 2    515,935                      ANP             Khadija Bibi
# 3    515,935                     PMLN           Iftikhar uddin
# 4    515,935  Pakistan Tehreek-e-Insaf             Abdul Latif

# %%
desire_col = ['NO. OF CONSTITUENCY', 'NAME OF PROVINCE', 'NAME OF CONSTITUENCY','Party','candidate_votes','candidate_share','outcome']
data = df_2024[desire_col]
